# %%
# %matplotlib inline

import h5py
import matplotlib.pyplot as plt
import numpy as np

data = h5py.File('./training_curve/training_curve.hdf5', 'r')

# %%
loss_d = data["Loss D"]
loss_g = data["Loss G"]

fig, ax = plt.subplots()

ax.plot(loss_d)
ax.plot(loss_g)
ax.set_yscale("log")
plt.show()

# %%
print(len(loss_d))
# Out:
# 750
